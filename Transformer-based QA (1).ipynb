# %%
import kagglehub

path = kagglehub.dataset_download("roblexnana/the-babi-tasks-for-nlp-qa-system")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/roblexnana/the-babi-tasks-for-nlp-qa-system?dataset_version_number=1...
# 100%|█████████████████████████████████████████████████████████████████████████████| 16.7M/16.7M [00:02<00:00, 5.83MB/s]
# Extracting files...
# Path to dataset files: C:\Users\ADMIN\.cache\kagglehub\datasets\roblexnana\the-babi-tasks-for-nlp-qa-system\versions\1

# %%
import os
import re

def load_babi_data(path):
    stories, questions, answers = [], [], []
    story = []

    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            idx, text = line.split(" ", 1)

            if idx == "1":
                story = []

            if "?" in text:
                q, a, _ = text.split("\t")
                stories.append(" ".join(story))
                questions.append(q.replace("?", ""))
                answers.append(a)
            else:
                story.append(text)

    return stories, questions, answers

# %%
train_path = r"C:\Users\ADMIN\.cache\kagglehub\datasets\roblexnana\the-babi-tasks-for-nlp-qa-system\versions\1\tasks_1-20_v1-2\en\qa1_single-supporting-fact_train.txt"
test_path = r"C:\Users\ADMIN\.cache\kagglehub\datasets\roblexnana\the-babi-tasks-for-nlp-qa-system\versions\1\tasks_1-20_v1-2\en\qa1_single-supporting-fact_test.txt"

train_stories, train_questions, train_answers = load_babi_data(train_path)
test_stories, test_questions, test_answers = load_babi_data(test_path)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(filters="")
tokenizer.fit_on_texts(train_stories + train_questions)

vocab_size = len(tokenizer.word_index) + 1

max_story_len = max(len(s.split()) for s in train_stories)
max_question_len = max(len(q.split()) for q in train_questions)

def vectorize(stories, questions):
    story_seq = pad_sequences(
        tokenizer.texts_to_sequences(stories),
        maxlen=max_story_len
    )
    question_seq = pad_sequences(
        tokenizer.texts_to_sequences(questions),
        maxlen=max_question_len
    )
    return story_seq, question_seq

# %%
X_story_train, X_q_train = vectorize(train_stories, train_questions)
X_story_test, X_q_test = vectorize(test_stories, test_questions)
print(train_stories)
print(train_questions)
print(train_answers)
# Out:
# ['Mary moved to the bathroom. John went to the hallway.', 'Mary moved to the bathroom. John went to the hallway. Daniel went back to the hallway. Sandra moved to the garden.', 'Mary moved to the bathroom. John went to the hallway. Daniel went back to the hallway. Sandra moved to the garden. John moved to the office. Sandra journeyed to the bathroom.', 'Mary moved to the bathroom. John went to the hallway. Daniel went back to the hallway. Sandra moved to the garden. John moved to the office. Sandra journeyed to the bathroom. Mary moved to the hallway. Daniel travelled to the office.', 'Mary moved to the bathroom. John went to the hallway. Daniel went back to the hallway. Sandra moved to the garden. John moved to the office. Sandra journeyed to the bathroom. Mary moved to the hallway. Daniel travelled to the office. John went back to the garden. John moved to the bedroom.', 'Sandra travelled to the office. Sandra went to the bathroom.', 'Sandra travelled to the office. Sandra went to the bathroom. Mary went to the bedroom. Daniel moved to the hallway.', 'Sandra travelled to the office. Sandra went to the bathroom. Mary went to the bedroom. Daniel moved to the hallway. John went to the garden. John travelled to the office.', 'Sandra travelled to the office. Sandra went to the bathroom. Mary went to the bedroom. Daniel moved to the hallway. John went to the garden. John travelled to the office. Daniel journeyed to the bedroom. Daniel travelled to the hallway.', 'Sandra travelled to the office. Sandra went to the bathroom. Mary went to the bedroom. Daniel moved to the hallway. John went to the garden. John travelled to the office. Daniel journeyed to the bedroom. Daniel travelled to the hallway. John went to the bedroom. John travelled to the office.', 'Mary went to the bedroom. John journeyed to the bathroom.', 'Mary went to the bedroom. John journeyed to the bathroom. Sandra journeyed to the hallway. John journeyed to the garden.', 'Mary went to the bedroom. John journeyed to the bathroom. Sandra journeyed to the hallway. John journeyed to the garden. John journeyed to the bathroom. Sandra journeyed to the garden.', 'Mary went to the bedroom. John journeyed to the bathroom. Sandra journeyed to the hallway. John journeyed to the garden. John journeyed to the bathroom. Sandra journeyed to the garden. Sandra went back to the bedroom. Daniel travelled to the bathroom.', 'Mary went to the bedroom. John journeyed to the bathroom. Sandra journeyed to the hallway. John journeyed to the garden. John journeyed to the bathroom. Sandra journeyed to the garden. Sandra went back to the bedroom. Daniel travelled to the bathroom. John went to the office. Mary moved to the office.', 'Daniel journeyed to the kitchen. Daniel journeyed to the bedroom.', 'Daniel journeyed to the kitchen. Daniel journeyed to the bedroom. Sandra moved to the garden. Sandra went back to the kitchen.', 'Daniel journeyed to the kitchen. Daniel journeyed to the bedroom. Sandra moved to the garden. Sandra went back to the kitchen. Daniel travelled to the office. Sandra went back to the hallway.', 'Daniel journeyed to the kitchen. Daniel journeyed to the bedroom. Sandra moved to the garden. Sandra went back to the kitchen. Daniel travelled to the office. Sandra went back to the hallway. Daniel journeyed to the hallway. Daniel went to the bathroom.', 'Daniel journeyed to the kitchen. Daniel journeyed to the bedroom. Sandra moved to the garden. Sandra went back to the kitchen. Daniel travelled to the office. Sandra went back to the hallway. Daniel journeyed to the hallway. Daniel went to the bathroom. John travelled to the garden. Daniel moved to the hallway.', 'Mary moved to the garden. John journeyed to the bathroom.', 'Mary moved to the garden. John journeyed to the bathroom. Sandra moved to the office. John moved to the kitchen.', 'Mary moved to the garden. John journeyed to the bathroom. Sandra moved to the office. John moved to the kitchen. Sandra went to the hallway. Ma ...
# ['Where is Mary ', 'Where is Daniel ', 'Where is Daniel ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Sandra ', 'Where is John ', 'Where is Daniel ', 'Where is John ', 'Where is Mary ', 'Where is John ', 'Where is John ', 'Where is Sandra ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Daniel ', 'Where is John ', 'Where is Mary ', 'Where is John ', 'Where is Sandra ', 'Where is John ', 'Where is Daniel ', 'Where is John ', 'Where is Daniel ', 'Where is John ', 'Where is Daniel ', 'Where is Mary ', 'Where is Sandra ', 'Where is Daniel ', 'Where is John ', 'Where is Daniel ', 'Where is Mary ', 'Where is John ', 'Where is Daniel ', 'Where is John ', 'Where is Sandra ', 'Where is Daniel ', 'Where is Daniel ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Sandra ', 'Where is John ', 'Where is Sandra ', 'Where is Daniel ', 'Where is Mary ', 'Where is Sandra ', 'Where is Sandra ', 'Where is John ', 'Where is John ', 'Where is Mary ', 'Where is Mary ', 'Where is John ', 'Where is Sandra ', 'Where is Mary ', 'Where is John ', 'Where is John ', 'Where is Daniel ', 'Where is Daniel ', 'Where is John ', 'Where is Daniel ', 'Where is Mary ', 'Where is Daniel ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Mary ', 'Where is Sandra ', 'Where is Mary ', 'Where is John ', 'Where is Sandra ', 'Where is Mary ', 'Where is Mary ', 'Where is Daniel ', 'Where is Mary ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Mary ', 'Where is John ', 'Where is Mary ', 'Where is Daniel ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Mary ', 'Where is John ', 'Where is John ', 'Where is John ', 'Where is Mary ', 'Where is Daniel ', 'Where is Mary ', 'Where is Mary ', 'Where is Mary ', 'Where is Mary ', 'Where is Daniel ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Mary ', 'Where is Mary ', 'Where is Mary ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Mary ', 'Where is John ', 'Where is Mary ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Daniel ', 'Where is Mary ', 'Where is Sandra ', 'Where is Mary ', 'Where is John ', 'Where is John ', 'Where is John ', 'Where is John ', 'Where is John ', 'Where is Daniel ', 'Where is Daniel ', 'Where is John ', 'Where is Daniel ', 'Where is John ', 'Where is Mary ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Daniel ', 'Where is John ', 'Where is Daniel ', 'Where is John ', 'Where is Daniel ', 'Where is John ', 'Where is Daniel ', 'Where is Mary ', 'Where is Sandra ', 'Where is Mary ', 'Where is Mary ', 'Where is Daniel ', 'Where is Daniel ', 'Where is John ', 'Where is John ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Sandra ', 'Where is John ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Daniel ', 'Where is Mary ', 'Where is John ', 'Where is John ', 'Where is Daniel ', 'Where is Mary ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Mary ', 'Where is Daniel ', 'Where is Sandra ', 'Where is John ', 'Where is Mary ', 'Where is Sandra ', 'Where is Daniel ', 'Where is Mary ', 'Where is Sandra ', 'Where is Mary ', 'Where is Mary ', 'Where is Mary ', 'Where is John ', 'Where is Mary ', 'Where is Mary ', 'Where is John ', 'Where is John ', 'Where is Mary ', 'Where is Daniel ', 'Where is Daniel ', 'Where is John ', 'Where is John ', 'Where is Sandra ', 'Where is Sandra ', 'Where is Mary ', 'Where is Mary ', 'Where is John ', 'Where is Mary ', 'Where is Daniel ', 'Where is Mary ', 'Where is Mary ', 'Where is Daniel ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Daniel ', 'Where is Sandra ', 'Where is Daniel ', 'Where is John ', 'Where is Daniel ', 'Where is Daniel ', 'Where is John ', 'Where is John ', 'Where is Daniel ', 'Where is John ', 'Where is Daniel ', 'Where is John ', 'Where is Mary ', 'Where is Sandra ', 'Wher ...
# ['bathroom', 'hallway', 'hallway', 'office', 'bathroom', 'bathroom', 'bathroom', 'bathroom', 'office', 'hallway', 'bathroom', 'bedroom', 'bathroom', 'bathroom', 'bedroom', 'bedroom', 'kitchen', 'hallway', 'hallway', 'hallway', 'bathroom', 'garden', 'kitchen', 'hallway', 'office', 'bathroom', 'bedroom', 'garden', 'hallway', 'garden', 'hallway', 'kitchen', 'bathroom', 'kitchen', 'garden', 'kitchen', 'bedroom', 'bedroom', 'kitchen', 'kitchen', 'office', 'office', 'office', 'kitchen', 'hallway', 'bedroom', 'bedroom', 'kitchen', 'bathroom', 'kitchen', 'garden', 'office', 'office', 'office', 'office', 'office', 'hallway', 'hallway', 'office', 'hallway', 'hallway', 'bathroom', 'bedroom', 'bedroom', 'kitchen', 'kitchen', 'bathroom', 'garden', 'kitchen', 'bathroom', 'garden', 'office', 'bathroom', 'hallway', 'office', 'garden', 'hallway', 'kitchen', 'bedroom', 'bedroom', 'office', 'bathroom', 'hallway', 'bathroom', 'kitchen', 'office', 'office', 'office', 'hallway', 'kitchen', 'bathroom', 'bathroom', 'kitchen', 'kitchen', 'hallway', 'bathroom', 'bedroom', 'bedroom', 'garden', 'kitchen', 'garden', 'kitchen', 'kitchen', 'hallway', 'hallway', 'garden', 'bathroom', 'bedroom', 'garden', 'bedroom', 'garden', 'garden', 'bedroom', 'kitchen', 'bathroom', 'hallway', 'hallway', 'garden', 'office', 'office', 'hallway', 'kitchen', 'bedroom', 'bedroom', 'bedroom', 'kitchen', 'bathroom', 'bathroom', 'kitchen', 'kitchen', 'bathroom', 'hallway', 'bathroom', 'hallway', 'hallway', 'bedroom', 'garden', 'garden', 'garden', 'bathroom', 'garden', 'bathroom', 'garden', 'bathroom', 'kitchen', 'office', 'bathroom', 'kitchen', 'office', 'office', 'hallway', 'hallway', 'kitchen', 'kitchen', 'office', 'bathroom', 'kitchen', 'kitchen', 'bathroom', 'office', 'bedroom', 'bathroom', 'kitchen', 'bathroom', 'office', 'bedroom', 'garden', 'bathroom', 'kitchen', 'bathroom', 'bathroom', 'bathroom', 'office', 'hallway', 'garden', 'hallway', 'hallway', 'bathroom', 'bathroom', 'bedroom', 'kitchen', 'kitchen', 'bedroom', 'bedroom', 'bedroom', 'bedroom', 'office', 'garden', 'kitchen', 'garden', 'bathroom', 'office', 'kitchen', 'bedroom', 'garden', 'garden', 'bedroom', 'garden', 'bathroom', 'kitchen', 'garden', 'garden', 'hallway', 'office', 'garden', 'kitchen', 'bathroom', 'kitchen', 'garden', 'kitchen', 'garden', 'office', 'bathroom', 'office', 'office', 'bedroom', 'bathroom', 'bedroom', 'office', 'bedroom', 'garden', 'garden', 'garden', 'bathroom', 'bathroom', 'bedroom', 'bedroom', 'bathroom', 'hallway', 'office', 'kitchen', 'kitchen', 'bedroom', 'garden', 'hallway', 'hallway', 'bathroom', 'garden', 'bedroom', 'garden', 'bathroom', 'garden', 'office', 'hallway', 'bathroom', 'garden', 'hallway', 'garden', 'garden', 'bedroom', 'hallway', 'bedroom', 'bedroom', 'kitchen', 'kitchen', 'office', 'garden', 'garden', 'bedroom', 'office', 'bathroom', 'bathroom', 'bathroom', 'office', 'hallway', 'kitchen', 'garden', 'garden', 'garden', 'garden', 'garden', 'kitchen', 'kitchen', 'office', 'kitchen', 'bathroom', 'hallway', 'bedroom', 'kitchen', 'kitchen', 'hallway', 'hallway', 'hallway', 'hallway', 'garden', 'kitchen', 'kitchen', 'office', 'bathroom', 'bedroom', 'hallway', 'hallway', 'kitchen', 'garden', 'bedroom', 'garden', 'kitchen', 'kitchen', 'garden', 'kitchen', 'bedroom', 'office', 'kitchen', 'office', 'kitchen', 'hallway', 'kitchen', 'kitchen', 'kitchen', 'bedroom', 'office', 'garden', 'bedroom', 'hallway', 'bathroom', 'kitchen', 'garden', 'bedroom', 'bedroom', 'kitchen', 'garden', 'bathroom', 'bathroom', 'hallway', 'garden', 'garden', 'bedroom', 'bathroom', 'bathroom', 'kitchen', 'bedroom', 'bedroom', 'bedroom', 'garden', 'hallway', 'office', 'kitchen', 'office', 'hallway', 'office', 'office', 'bathroom', 'kitchen', 'hallway', 'bedroom', 'office', 'bedroom', 'bedroom', 'kitchen', 'bedroom', 'garden', 'bathroom', 'garden', 'garden', 'office', 'bathroom', 'bedroom', 'kitchen', 'office', 'office', 'hallway', 'garden', 'hallway', 'garden', 'bedroom', 'bathroom', 'kitchen', 'office', 'k ...

# %%
answer_tokenizer = Tokenizer(filters="")
answer_tokenizer.fit_on_texts(train_answers)

y_train = answer_tokenizer.texts_to_sequences(train_answers)
y_test = answer_tokenizer.texts_to_sequences(test_answers)

y_train = [a[0] for a in y_train]
y_test = [a[0] for a in y_test]

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, Dense, LayerNormalization, MultiHeadAttention, GlobalAveragePooling1D
from tensorflow.keras.models import Model

embedding_dim = 64
num_heads = 4
ff_dim = 128

story_input = Input(shape=(max_story_len,))
question_input = Input(shape=(max_question_len,))

embedding = Embedding(vocab_size, embedding_dim)

story_embed = embedding(story_input)
question_embed = embedding(question_input)

attention = MultiHeadAttention(num_heads=num_heads, key_dim=embedding_dim)
attn_output = attention(
    query=question_embed,
    value=story_embed,
    key=story_embed
)

x = LayerNormalization()(attn_output)
x = GlobalAveragePooling1D()(x)
x = Dense(64, activation="relu")(x)
output = Dense(len(answer_tokenizer.word_index) + 1, activation="softmax")(x)

model = Model(inputs=[story_input, question_input], outputs=output)

# %%
import numpy as np

y_train = np.array(y_train)
y_test = np.array(y_test)

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    [X_story_train, X_q_train],
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1
)
# Out:
# Epoch 1/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.1603 - loss: 1.8675 - val_accuracy: 0.1100 - val_loss: 1.8535
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.1869 - loss: 1.8195 - val_accuracy: 0.1300 - val_loss: 1.8181
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.2005 - loss: 1.7836 - val_accuracy: 0.2200 - val_loss: 1.7228
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.2489 - loss: 1.7328 - val_accuracy: 0.1900 - val_loss: 1.7131
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.2802 - loss: 1.6780 - val_accuracy: 0.2300 - val_loss: 1.6639
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3381 - loss: 1.6035 - val_accuracy: 0.3900 - val_loss: 1.5586
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3770 - loss: 1.5054 - val_accuracy: 0.3200 - val_loss: 1.7214
# Epoch 8/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3707 - loss: 1.5564 - val_accuracy: 0.4100 - val_loss: 1.3787
# Epoch 9/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4475 - loss: 1.3564 - val_accuracy: 0.4700 - val_loss: 1.2917
# Epoch 10/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4613 - loss: 1.3324 - val_accuracy: 0.5300 - val_loss: 1.2100
# Epoch 11/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4603 - loss: 1.2704 - val_accuracy: 0.4800 - val_loss: 1.2600
# Epoch 12/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4962 - loss: 1.2111 - val_accuracy: 0.4500 - val_loss: 1.2115
# Epoch 13/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4993 - loss: 1.1747 - val_accuracy: 0.4700 - val_loss: 1.2287
# Epoch 14/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5103 - loss: 1.1954 - val_accuracy: 0.4100 - val_loss: 1.2507
# Epoch 15/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5300 - loss: 1.1706 - val_accuracy: 0.4900 - val_loss: 1.2156
# Epoch 16/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4776 - loss: 1.2138 - val_accuracy: 0.3900 - val_loss: 1.3741
# Epoch 17/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5055 - loss: 1.1865 - val_accuracy: 0.5100 - val_loss: 1.2048
# Epoch 18/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5087 - loss: 1.1461 - val_accuracy: 0.4700 - val_loss: 1.2166
# Epoch 19/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5259 - loss: 1.1315 - val_accuracy: 0.4500 - val_loss: 1.2226
# Epoch 20/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4732 - loss: 1.1906 - val_accuracy: 0.4900 - val_loss: 1.2112

# %%
loss, acc = model.evaluate([X_story_test, X_q_test], y_test)
print("Transformer QA Accuracy:", acc)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4110 - loss: 1.3403
# Transformer QA Accuracy: 0.4129999876022339

# %%
from tensorflow.keras.layers import LSTM, Concatenate
story_lstm = LSTM(64)(story_embed)
question_lstm = LSTM(64)(question_embed)

merged = Concatenate()([story_lstm, question_lstm])
dense = Dense(64, activation="relu")(merged)
lstm_output = Dense(len(answer_tokenizer.word_index) + 1, activation="softmax")(dense)

lstm_model = Model([story_input, question_input], lstm_output)

# %%
lstm_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

lstm_model.fit(
    [X_story_train, X_q_train],
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1
)

lstm_loss, lstm_acc = lstm_model.evaluate([X_story_test, X_q_test], y_test)
print("LSTM QA Accuracy:", lstm_acc)
# Out:
# Epoch 1/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - accuracy: 0.2922 - loss: 1.8827 - val_accuracy: 0.4400 - val_loss: 1.6765
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.4523 - loss: 1.6054 - val_accuracy: 0.5600 - val_loss: 1.4982
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.5593 - loss: 1.3754 - val_accuracy: 0.5100 - val_loss: 1.2945
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.5483 - loss: 1.2575 - val_accuracy: 0.5200 - val_loss: 1.3931
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.6132 - loss: 1.0954 - val_accuracy: 0.5300 - val_loss: 1.2714
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.5797 - loss: 1.1234 - val_accuracy: 0.5600 - val_loss: 1.2062
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6047 - loss: 1.0650 - val_accuracy: 0.5000 - val_loss: 1.2453
# Epoch 8/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.6020 - loss: 1.0503 - val_accuracy: 0.5000 - val_loss: 1.1412
# Epoch 9/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.5986 - loss: 1.0689 - val_accuracy: 0.4900 - val_loss: 1.2135
# Epoch 10/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.5962 - loss: 1.0260 - val_accuracy: 0.5000 - val_loss: 1.1860
# Epoch 11/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.5898 - loss: 1.0228 - val_accuracy: 0.5000 - val_loss: 1.2138
# Epoch 12/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.5939 - loss: 0.9981 - val_accuracy: 0.5200 - val_loss: 1.2183
# Epoch 13/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.6010 - loss: 0.9631 - val_accuracy: 0.5200 - val_loss: 1.1787
# Epoch 14/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6243 - loss: 0.9610 - val_accuracy: 0.5400 - val_loss: 1.1567
# Epoch 15/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.6237 - loss: 0.9688 - val_accuracy: 0.4900 - val_loss: 1.2062
# Epoch 16/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.6097 - loss: 0.9075 - val_accuracy: 0.4900 - val_loss: 1.1396
# Epoch 17/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6107 - loss: 0.9265 - val_accuracy: 0.5000 - val_loss: 1.1602
# Epoch 18/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6501 - loss: 0.8382 - val_accuracy: 0.5500 - val_loss: 1.1641
# Epoch 19/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.6687 - loss: 0.8671 - val_accuracy: 0.4800 - val_loss: 1.1694
# Epoch 20/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6550 - loss: 0.8485 - val_accuracy: 0.4800 - val_loss: 1.2638
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4642 - loss: 1.3353
# LSTM QA Accuracy: 0.47699999809265137
